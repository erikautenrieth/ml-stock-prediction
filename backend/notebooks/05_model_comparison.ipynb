# %% [markdown]
# # 05 - Model Comparison
#
# Vergleich verschiedener Modelle & Konfigurationen.
#
# **Ziele:**
# - MLflow Runs vergleichen
# - Metriken gegenüberstellen
# - Bestes Modell auswählen
# - Model Registry aktualisieren
