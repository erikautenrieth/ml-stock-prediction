# %% [markdown]
# # 01 - Data Exploration
#
# Explorative Datenanalyse der Rohdaten (Aktienkurse).
#
# **Ziele:**
# - Daten laden & Überblick verschaffen
# - Zeitreihen visualisieren
# - Fehlende Werte & Ausreißer identifizieren
# - Statistische Kennzahlen berechnen

# %%
from backend.workflows.fetch_data import get_data

training_df, last_day_df = get_data()

print(f"Training: {training_df.shape}")
print(f"Last Day: {last_day_df.shape}")
print(training_df["Target"].value_counts())
training_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2026-03-08 19:09:56 [info     ] calc_indicators: 33 rows dropped (NaN), 6404 remaining
# 2026-03-08 19:10:04 [info     ] fetch_extra_market_data: filled 513 NaN values, 0 remaining
# Training: (6394, 53)
# Last Day: (1, 52)
# Target
# 1    3854
# 0    2540
# Name: count, dtype: int64
# Price             Close        Volume  Target       SMA 10       EMA 10  \
# Date
# 2000-09-18  1444.510010  9.625000e+08       0  1484.369006  1479.509808
# 2000-09-19  1459.900024  1.024900e+09       0  1479.651013  1475.944393
# 2000-09-20  1451.339966  1.104000e+09       0  1475.560010  1471.470861
# 2000-09-21  1449.050049  1.105400e+09       0  1470.214014  1467.394350
# 2000-09-22  1448.719971  1.185500e+09       0  1465.636011  1463.999008
# ...                 ...           ...     ...          ...          ...
# 2026-02-13  6836.169922  5.718360e+09       1  6902.469971  6897.208424
# ...
