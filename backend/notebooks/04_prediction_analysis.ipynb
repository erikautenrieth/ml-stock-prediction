# %% [markdown]
# # 04 - Prediction Analysis
#
# Vorhersagen generieren & analysieren.
#
# **Ziele:**
# - Modell laden & Vorhersagen erstellen
# - Predicted vs. Actual vergleichen
# - Residuen analysieren
# - Vorhersage-Konfidenz bewerten
